# %%
! sudo apt install -y fluidsynth
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   adwaita-icon-theme alsa-topology-conf alsa-ucm-conf at-spi2-core
#   dconf-gsettings-backend dconf-service fluid-soundfont-gm
#   gsettings-desktop-schemas gtk-update-icon-cache humanity-icon-theme
#   libasound2 libasound2-data libasyncns0 libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libcairo-gobject2 libcolord2 libdconf1
#   libdecor-0-0 libdecor-0-plugin-1-cairo libdouble-conversion3 libegl-mesa0
#   libegl1 libepoxy0 libevdev2 libflac8 libfluidsynth3 libgbm1
#   libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgtk-3-0
#   libgtk-3-bin libgtk-3-common libinput-bin libinput10 libinstpatch-1.0-2
#   libjack-jackd2-0 libmd4c0 libmtdev1 libogg0 libopus0 libpcre2-16-0 libpulse0
#   libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5
#   librsvg2-2 librsvg2-common libsamplerate0 libsdl2-2.0-0 libsndfile1
#   libvorbis0a libvorbisenc2 libwacom-bin libwacom-common libwacom9
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libxcb-icccm4
#   libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxdamage1 libxkbcommon-x11-0
#   libxkbcommon0 qsynth qt5-gtk-platformtheme qttranslations5-l10n
#   session-migration timgm6mb-soundfont ubuntu-mono
# Suggested packages:
#   fluid-soundfont-gs libasound2-plugins alsa-utils colord gvfs jackd2
#   opus-tools pulseaudio qt5-image-formats-plugins qtwayland5 librsvg2-bin
#   jackd
# The following NEW packages will be installed:
#   adwaita-icon-theme alsa-topology-conf alsa-ucm-conf at-spi2-core
#   dconf-gsettings-backend dconf-service fluid-soundfont-gm fluidsynth
#   gsettings-desktop-schemas gtk-update-icon-cache humanity-icon-theme
#   libasound2 libasound2-data libasyncns0 libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libcairo-gobject2 libcolord2 libdconf1
#   libdecor-0-0 libdecor-0-plugin-1-cairo libdouble-conversion3 libegl-mesa0
#   libegl1 libepoxy0 libevdev2 libflac8 libfluidsynth3 libgbm1
#   libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgtk-3-0
#   libgtk-3-bin libgtk-3-common libinput-bin libinput10 libinstpatch-1.0-2
#   libjack-jackd2-0 libmd4c0 libmtdev1 libogg0 libopus0 libpcre2-16-0 libpulse0
#   libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5
#   librsvg2-2 librsvg2-common libsamplerate0 libsdl2-2.0-0 libsndfile1
#   libvorbis0a libvorbisenc2 libwacom-bin libwacom-common libwacom9
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libxcb-icccm4
#   libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxdamage1 libxkbcommon-x11-0
#   libxkbcommon0 qsynth qt5-gtk-platformtheme qttranslations5-l10n
#   session-migration timgm6mb-soundfont ubuntu-mono
# 0 upgraded, 83 newly installed, 0 to remove and 111 not upgraded.
# Need to get 164 MB of archives.
# After this operation, 279 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcre2-16-0 amd64 10.39-3ubuntu0.1 [203 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-server0 amd64 1.20.0-1ubuntu0.1 [34.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm1 amd64 22.0.5-0ubuntu0.1 [32.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl-mesa0 amd64 22.0.5-0ubuntu0.1 [112 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl1 amd64 1.4.0-1 [28.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.1 [19.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.1 [131 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon0 amd64 1.4.0-1 [125 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-common all 2.42.8+dfsg-1ubuntu0.2 [5,530 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf-2.0-0 amd64 2.42.8+dfsg-1ubuntu0.2 [148 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gtk-update-icon-cache amd64 3.24.33-1ubuntu2 [31.4 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 humanity-icon-theme all 0.6.16 [1,282 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 ubuntu-mono all 20.10-0ubuntu2 [153 kB]3m
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 adwaita-icon-theme all 41.0-1ubuntu1 [3,444 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 alsa-topology-conf all 1.2.5.1-2 [15.5 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasound2-data all 1.2.6.1-1ubuntu1 [19.1 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasound2 amd64 1.2.6.1-1ubuntu1 [390 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 alsa-ucm-conf all 1.2.6.3-1ubuntu1.1 [41.1 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdconf1 amd64 0.40.0-3 [40.5 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 dconf-service amd64 0.40.0-3 [28.5 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 dconf-gsettings-backend amd64 0.40.0-3 [22.8 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluid-soundfont-gm all 3.1-5.3 [130 MB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libogg0 amd64 1.3.5-0ubuntu3 [22.9 kB]33m
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libflac8 amd64 1.3.3-2ubuntu0.1 [111 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopus0 amd64 1.3.1-0.1build2 [203 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbis0a amd64 1.3.7-1build2 [99.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisenc2 amd64 1.3.7-1build2 [82.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsndfile1 amd64 1.0.31-2build1 [196 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsamplerate0 amd64 0.2.2-1build1 [1,359 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjack-jackd2-0 amd64 1.9.20~dfsg-1 [293 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasyncns0 amd64 0.8-6build2 [12.8 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse0 amd64 1:15.99.1+dfsg1-1ubuntu2 [297 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-0 amd64 0.1.0-3build1 [15.1 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-cursor0 amd64 1.20.0-1ubuntu0.1 [10.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-egl1 amd64 1.20.0-1ubuntu0.1 [5,582 B]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsdl2-2.0-0 amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [582 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluidsynth amd64 2.2.5-1 [27.4 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-gobject2 amd64 1.16.0-5ubuntu2 [19.4 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolord2 amd64 1.4.6-1 [155 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-plugin-1-cairo amd64 0.1.0-3build1 [20.4 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepoxy0 amd64 1.5.10-1 [237 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.42.8+dfsg-1ubuntu0.2 [14.2 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdamage1 amd64 1:1.1.5-2build2 [7,154 B]
# Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2 [239 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2 [3,053 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2 [69.5 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 librsvg2-2 amd64 2.52.5+dfsg-3 [3,020 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 librsvg2-common amd64 2.52.5+dfsg-3 [17.7 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qsynth amd64 0.9.6-1 [305 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 164 MB in 47s (3,502 kB/s)
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package libdouble-conversion3:amd64.
# (Reading database ... 93818 files and directories currently installed.)
# Preparing to unpack .../00-libdouble-conversion3_3.1.7-4_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libpcre2-16-0:amd64.
# Preparing to unpack .../01-libpcre2-16-0_10.39-3ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-16-0:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../02-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../03-libwayland-server0_1.20.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libwayland-server0:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../04-libgbm1_22.0.5-0ubuntu0.1_amd64.deb ...
# Unpacking libgbm1:amd64 (22.0.5-0ubuntu0.1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libegl-mesa0:amd64.
# Preparing to unpack .../05-libegl-mesa0_22.0.5-0ubuntu0.1_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (22.0.5-0ubuntu0.1) ...
# Selecting previously unselected package libegl1:amd64.
# Preparing to unpack .../06-libegl1_1.4.0-1_amd64.deb ...
# Unpacking libegl1:amd64 (1.4.0-1) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../07-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../08-libmtdev1_1.1.6-1build4_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../09-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../10-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../11-libinput-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../12-libinput10_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../13-libmd4c0_0.4.8-1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../14-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../15-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../16-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../17-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../18-libxcb-image0_0.4.0-2_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../19-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../20-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../21-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../22-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../23-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon0:amd64.
# Preparing to unpack .../24-libxkbcommon0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon0:amd64 (1.4.0-1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../25-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../26-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../27-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../28-libqt5svg5_5.15.3-1_amd64.deb ...
# 7Progress: [ 17%] [#########.................................................] 8Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../29-libgdk-pixbuf2.0-common_2.42.8+dfsg-1ubuntu0.2_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.42.8+dfsg-1ubuntu0.2) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libgdk-pixbuf-2.0-0:amd64.
# Preparing to unpack .../30-libgdk-pixbuf-2.0-0_2.42.8+dfsg-1ubuntu0.2_amd64.deb ...
# Unpacking libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package gtk-update-icon-cache.
# Preparing to unpack .../31-gtk-update-icon-cache_3.24.33-1ubuntu2_amd64.deb ...
# Unpacking gtk-update-icon-cache (3.24.33-1ubuntu2) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package humanity-icon-theme.
# Preparing to unpack .../32-humanity-icon-theme_0.6.16_all.deb ...
# Unpacking humanity-icon-theme (0.6.16) ...
# Selecting previously unselected package ubuntu-mono.
# Preparing to unpack .../33-ubuntu-mono_20.10-0ubuntu2_all.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking ubuntu-mono (20.10-0ubuntu2) ...
# Selecting previously unselected package adwaita-icon-theme.
# Preparing to unpack .../34-adwaita-icon-theme_41.0-1ubuntu1_all.deb ...
# Unpacking adwaita-icon-theme (41.0-1ubuntu1) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package alsa-topology-conf.
# Preparing to unpack .../35-alsa-topology-conf_1.2.5.1-2_all.deb ...
# Unpacking alsa-topology-conf (1.2.5.1-2) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../36-libasound2-data_1.2.6.1-1ubuntu1_all.deb ...
# Unpacking libasound2-data (1.2.6.1-1ubuntu1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libasound2:amd64.
# Preparing to unpack .../37-libasound2_1.2.6.1-1ubuntu1_amd64.deb ...
# Unpacking libasound2:amd64 (1.2.6.1-1ubuntu1) ...
# Selecting previously unselected package alsa-ucm-conf.
# Preparing to unpack .../38-alsa-ucm-conf_1.2.6.3-1ubuntu1.1_all.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking alsa-ucm-conf (1.2.6.3-1ubuntu1.1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../39-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../40-libdconf1_0.40.0-3_amd64.deb ...
# Unpacking libdconf1:amd64 (0.40.0-3) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../41-dconf-service_0.40.0-3_amd64.deb ...
# Unpacking dconf-service (0.40.0-3) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../42-dconf-gsettings-backend_0.40.0-3_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.40.0-3) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../43-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../44-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../45-at-spi2-core_2.44.0-3_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package fluid-soundfont-gm.
# Preparing to unpack .../46-fluid-soundfont-gm_3.1-5.3_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.3) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../47-libogg0_1.3.5-0ubuntu3_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.5-0ubuntu3) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../48-libflac8_1.3.3-2ubuntu0.1_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.3-2ubuntu0.1) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../49-libopus0_1.3.1-0.1build2_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0.1build2) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../50-libvorbis0a_1.3.7-1build2_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libvorbis0a:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../51-libvorbisenc2_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.7-1build2) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../52-libsndfile1_1.0.31-2build1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.31-2build1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../53-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../54-libsamplerate0_0.2.2-1build1_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.2.2-1build1) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../55-libjack-jackd2-0_1.9.20~dfsg-1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../56-libasyncns0_0.8-6build2_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6build2) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../57-libpulse0_1%3a15.99.1+dfsg1-1ubuntu2_amd64.deb ...
# Unpacking libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2) ...
# Selecting previously unselected package libdecor-0-0:amd64.
# Preparing to unpack .../58-libdecor-0-0_0.1.0-3build1_amd64.deb ...
# Unpacking libdecor-0-0:amd64 (0.1.0-3build1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../59-libwayland-cursor0_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-egl1:amd64.
# Preparing to unpack .../60-libwayland-egl1_1.20.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../61-libsdl2-2.0-0_2.0.20+dfsg-2ubuntu1.22.04.1_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../62-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../63-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package fluidsynth.
# Preparing to unpack .../64-fluidsynth_2.2.5-1_amd64.deb ...
# Unpacking fluidsynth (2.2.5-1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../65-libatk1.0-data_2.36.0-3build1_all.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../66-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../67-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libcairo-gobject2:amd64.
# Preparing to unpack .../68-libcairo-gobject2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libcolord2:amd64.
# Preparing to unpack .../69-libcolord2_1.4.6-1_amd64.deb ...
# Unpacking libcolord2:amd64 (1.4.6-1) ...
# Selecting previously unselected package libdecor-0-plugin-1-cairo:amd64.
# Preparing to unpack .../70-libdecor-0-plugin-1-cairo_0.1.0-3build1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libdecor-0-plugin-1-cairo:amd64 (0.1.0-3build1) ...
# Selecting previously unselected package libepoxy0:amd64.
# Preparing to unpack .../71-libepoxy0_1.5.10-1_amd64.deb ...
# Unpacking libepoxy0:amd64 (1.5.10-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../72-libgdk-pixbuf2.0-bin_2.42.8+dfsg-1ubuntu0.2_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../73-libxdamage1_1%3a1.1.5-2build2_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.5-2build2) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../74-libgtk-3-common_3.24.33-1ubuntu2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../75-libgtk-3-0_3.24.33-1ubuntu2_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../76-libgtk-3-bin_3.24.33-1ubuntu2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../77-librsvg2-2_2.52.5+dfsg-3_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking librsvg2-2:amd64 (2.52.5+dfsg-3) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../78-librsvg2-common_2.52.5+dfsg-3_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../79-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qsynth.
# Preparing to unpack .../80-qsynth_0.9.6-1_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking qsynth (0.9.6-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../81-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../82-qttranslations5-l10n_5.15.3-1_all.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up libwayland-server0:amd64 (1.20.0-1ubuntu0.1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libxdamage1:amd64 (1:1.1.5-2build2) ...
# Setting up libogg0:amd64 (1.3.5-0ubuntu3) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libgbm1:amd64 (22.0.5-0ubuntu0.1) ...
# Setting up libgdk-pixbuf2.0-common (2.42.8+dfsg-1ubuntu0.2) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# 7Progress: [ 55%] [################################..........................] 8Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libpcre2-16-0:amd64 (10.39-3ubuntu0.1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libcolord2:amd64 (1.4.6-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libflac8:amd64 (1.3.3-2ubuntu0.1) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libdconf1:amd64 (0.40.0-3) ...
# Setting up libasound2-data (1.2.6.1-1ubuntu1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libegl-mesa0:amd64 (22.0.5-0ubuntu0.1) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libepoxy0:amd64 (1.5.10-1) ...
# Setting up libopus0:amd64 (1.3.1-0.1build2) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libvorbis0a:amd64 (1.3.7-1build2) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up alsa-topology-conf (1.2.5.1-2) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libasyncns0:amd64 (0.8-6build2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libasound2:amd64 (1.2.6.1-1ubuntu1) ...
# Setting up libegl1:amd64 (1.4.0-1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libmd4c0:amd64 (0.4.8-1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libdecor-0-0:amd64 (0.1.0-3build1) ...
# Setting up fluid-soundfont-gm (3.1-5.3) ...
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# 7Progress: [ 72%] [#########################################.................] 8Setting up libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.2) ...
# Setting up libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libsamplerate0:amd64 (0.2.2-1build1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up timgm6mb-soundfont (1.3-5) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libvorbisenc2:amd64 (1.3.7-1build2) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libwacom-common (2.2.0-1) ...
# Setting up libxkbcommon0:amd64 (1.4.0-1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up gtk-update-icon-cache (3.24.33-1ubuntu2) ...
# Setting up alsa-ucm-conf (1.2.6.3-1ubuntu1.1) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libwacom9:amd64 (2.2.0-1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up dconf-service (0.40.0-3) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libinput-bin (1.20.0-1ubuntu0.1) ...
# Setting up librsvg2-2:amd64 (2.52.5+dfsg-3) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libdecor-0-plugin-1-cairo:amd64 (0.1.0-3build1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up librsvg2-common:amd64 (2.52.5+dfsg-3) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libsndfile1:amd64 (1.0.31-2build1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libinput10:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up dconf-gsettings-backend:amd64 (0.40.0-3) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up qsynth (0.9.6-1) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up fluidsynth (2.2.5-1) ...
# Created symlink /etc/systemd/user/default.target.wants/fluidsynth.service → /usr/lib/systemd/user/fluidsynth.service.
# Setting up adwaita-icon-theme (41.0-1ubuntu1) ...
# 7Progress: [ 94%] [######################################################....] 8update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up humanity-icon-theme (0.6.16) ...
# Setting up ubuntu-mono (20.10-0ubuntu2) ...
# 7Progress: [ 95%] [#######################################################...] 8Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for udev (249.11-0ubuntu3.4) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.1-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2) ...
# 7Progress: [ 97%] [########################################################..] 8Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Setting up libgtk-3-bin (3.24.33-1ubuntu2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up at-spi2-core (2.44.0-3) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.2) ...
#
# Scanning processes...                                                                            ]
# Scanning candidates...
# Scanning processor microcode...
# Scanning linux images...
#
# Failed to retrieve available kernel versions.
#
# Failed to check for processor microcode upgrades.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.

# %%
! pip install --upgrade pyfluidsynth
# Out:
# Collecting pyfluidsynth
#   Downloading pyFluidSynth-1.3.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in /root/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pyfluidsynth) (1.23.5)
# Installing collected packages: pyfluidsynth
# Successfully installed pyfluidsynth-1.3.1

# %%
! pip install pretty_midi
# Out:
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 2.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.7.0 in /root/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pretty_midi) (1.23.5)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /root/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pretty_midi) (1.16.0)
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591938 sha256=540169903744b3d411d2f049b2007f79ee1e66104c387d6716a2c765eee76470
#   Stored in directory: /root/.cache/pip/wheels/c6/da/73/f06afb9e786d5267c6f36636c74c324b1aa4d99caf570e7cd8
# Successfully built pretty_midi
# Installing collected packages: mido, pretty_midi
# Successfully installed mido-1.2.10 pretty_midi-0.2.9

# %%
import collections
import datetime
import fluidsynth
import glob
import numpy as np
import pathlib
import pandas as pd
import pretty_midi
import seaborn as sns
import tensorflow as tf

from IPython import display
from matplotlib import pyplot as plt
from typing import Dict, List, Optional, Sequence, Tuple
# Out:
# 2022-12-05 12:59:15.610530: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-05 12:59:18.156573: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-05 12:59:18.156612: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-05 12:59:21.950486: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-05 12:59:45.078690: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-05 12:59:45.079431: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-05 12:59:45.079491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# Sampling rate for audio playback
_SAMPLING_RATE = 16000

# %%
import os

my_files = []
directory = 'raw_data/Chopin'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        my_files.append(f)

        
my_files
# Out:
# ['raw_data/Chopin/chpn-p21_format0.mid',
#  'raw_data/Chopin/chp_op18_format0.mid',
#  'raw_data/Chopin/chpn-p6_format0.mid',
#  'raw_data/Chopin/chpn-p24_format0.mid',
#  'raw_data/Chopin/chpn_op25_e12_format0.mid',
#  'raw_data/Chopin/chpn_op23_format0.mid',
#  'raw_data/Chopin/chpn-p8_format0.mid',
#  'raw_data/Chopin/chpn_op10_e05_format0.mid',
#  'raw_data/Chopin/chpn_op27_1_format0.mid',
#  'raw_data/Chopin/chpn-p9_format0.mid',
#  'raw_data/Chopin/chpn-p12_format0.mid',
#  'raw_data/Chopin/chpn-p2_format0.mid',
#  'raw_data/Chopin/chpn_op25_e11_format0.mid',
#  'raw_data/Chopin/chpn-p13_format0.mid',
#  'raw_data/Chopin/chpn-p18_format0.mid',
#  'raw_data/Chopin/chpn-p5_format0.mid',
#  'raw_data/Chopin/chpn_op33_2_format0.mid',
#  'raw_data/Chopin/chpn-p1_format0.mid',
#  'raw_data/Chopin/chpn-p15_format0.mid',
#  'raw_data/Chopin/chpn_op25_e1_format0.mid',
#  'raw_data/Chopin/chpn-p10_format0.mid',
#  'raw_data/Chopin/chpn_op25_e4_format0.mid',
#  'raw_data/Chopin/chpn-p3_format0.mid',
#  'raw_data/Chopin/chpn_op7_1_format0.mid',
#  'raw_data/Chopin/chpn-p4_format0.mid',
#  'raw_data/Chopin/chpn_op35_4_format0.mid',
#  'raw_data/Chopin/chpn_op35_2_format0.mid',
#  'raw_data/Chopin/chpn-p16_format0.mid',
#  'raw_data/Chopin/chpn_op10_e01_format0.mid',
#  'raw_data/Chopin/chpn-p19_format0.mid',
#  'raw_data/Chopin/chpn-p22_format0.mid',
#  'raw_data/Chopin/chpn_op33_4_format0.mid',
#  'raw_data/Chopin/chpn_op66_format0.mid',
#  'raw_data/Chopin/chpn_op7_2_format0.mid',
#  'raw_data/Chopin/chpn_op27_2_format0.mid',
#  'raw_data/Chopin/chpn_op10_e12_format0.mid',
#  'raw_data/Chopin/chpn_op53_format0.mid',
#  'raw_data/Chopin/chp_op31_format0.mid']

# %%
midi_files = []
for file in my_files : 
    midi_data = pretty_midi.PrettyMIDI(file)
    midi_files.append(midi_data)
    
midi_files
# Out:
# [<pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c87257370>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c88aa9fc0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c87166590>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c86742f80>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c8691c730>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c85ac4ca0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c871671c0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c889ffe20>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c867b9270>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c865c40d0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c868546a0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c88e3b460>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c8715e830>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c868cac50>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c865c5840>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c88e3b490>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c86742b30>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c8675f7c0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c86905060>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c8694fac0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c85a071c0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c85ac63b0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c84de3130>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c867ba980>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c85558130>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c858e59f0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c8675c1c0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c866f4970>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c86822d40>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c865c4ca0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c84b2b2e0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c84b840a0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c84c8d180>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c8694e200>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c866be320>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c85ac43a0>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c84b90190>,
#  <pretty_midi.pretty_midi.PrettyMIDI at 0x7f7c85558310>]

# %%
nb_of_files = len(midi_files)
nb_of_files
# Out:
# 38

# %%
exploration_file = midi_files[5]
exploration_file

# %%
def display_audio(pm: pretty_midi.PrettyMIDI, seconds=30):
    waveform = pm.fluidsynth(fs=_SAMPLING_RATE)
  # Take a sample of the generated waveform to mitigate kernel resets
    waveform_short = waveform[:seconds*_SAMPLING_RATE]
    return display.Audio(waveform_short, rate=_SAMPLING_RATE)

# %%
display_audio(exploration_file)
# Out:
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('Number of instruments:', len(exploration_file.instruments))
instrument = exploration_file.instruments[0]
instrument_name = pretty_midi.program_to_instrument_name(instrument.program)
print('Instrument name:', instrument_name)
# Out:
# Number of instruments: 1
# Instrument name: Acoustic Grand Piano

# %%
for i, note in enumerate(instrument.notes[:10]):
    note_name = pretty_midi.note_number_to_name(note.pitch)
    duration = note.end - note.start
    print(f'{i}: pitch={note.pitch}, note_name={note_name},'
          f' duration={duration:.4f}')
# Out:
# 0: pitch=36, note_name=C2, duration=2.1712
# 1: pitch=48, note_name=C3, duration=2.1712
# 2: pitch=39, note_name=D#2, duration=0.4079
# 3: pitch=51, note_name=D#3, duration=0.4079
# 4: pitch=44, note_name=G#2, duration=0.3896
# 5: pitch=56, note_name=G#3, duration=0.3896
# 6: pitch=46, note_name=A#2, duration=0.4054
# 7: pitch=58, note_name=A#3, duration=0.4054
# 8: pitch=48, note_name=C3, duration=0.3871
# 9: pitch=60, note_name=C4, duration=0.3871

# %%
def midi_to_notes(midi_file: str) -> pd.DataFrame:
    pm = midi_file
    instrument = pm.instruments[0]
    notes = collections.defaultdict(list)

    # Sort the notes by start time
    sorted_notes = sorted(instrument.notes, key=lambda note: note.start)
    prev_start = sorted_notes[0].start

    for note in sorted_notes:
        start = note.start
        end = note.end
        notes['pitch'].append(note.pitch)
        notes['start'].append(start)
        notes['end'].append(end)
        notes['step'].append(start - prev_start)
        notes['duration'].append(end - start)
        prev_start = start

    return pd.DataFrame({name: np.array(value) for name, value in notes.items()})

# %%
raw_notes = midi_to_notes(exploration_file)
raw_notes.head()
# Out:
#    pitch     start       end      step  duration
# 0     36  0.001811  2.172967  0.000000  2.171157
# 1     48  0.001811  2.172967  0.000000  2.171157
# 2     39  2.172967  2.580909  2.171157  0.407942
# 3     51  2.172967  2.580909  0.000000  0.407942
# 4     44  2.580909  2.970519  0.407942  0.389610

# %%
get_note_names = np.vectorize(pretty_midi.note_number_to_name)
sample_note_names = get_note_names(raw_notes['pitch'])
sample_note_names[:10]
# Out:
# array(['C2', 'C3', 'D#2', 'D#3', 'G#2', 'G#3', 'A#2', 'A#3', 'C3', 'C4'],
#       dtype='<U3')

# %%
def plot_piano_roll(notes: pd.DataFrame, count: Optional[int] = None):
    if count:
        title = f'First {count} notes'
    else:
        title = f'Whole track'
        count = len(notes['pitch'])
    plt.figure(figsize=(20, 4))
    plot_pitch = np.stack([notes['pitch'], notes['pitch']], axis=0)
    plot_start_stop = np.stack([notes['start'], notes['end']], axis=0)
    plt.plot(
      plot_start_stop[:, :count], plot_pitch[:, :count], color="b", marker=".")
    plt.xlabel('Time [s]')
    plt.ylabel('Pitch')
    _ = plt.title(title)

# %%
plot_piano_roll(raw_notes, count=100)

# %%
plot_piano_roll(raw_notes)

# %%
def plot_distributions(notes: pd.DataFrame, drop_percentile=2.5):
    plt.figure(figsize=[15, 5])
    plt.subplot(1, 3, 1)
    sns.histplot(notes, x="pitch", bins=20)

    plt.subplot(1, 3, 2)
    max_step = np.percentile(notes['step'], 100 - drop_percentile)
    sns.histplot(notes, x="step", bins=np.linspace(0, max_step, 21))

    plt.subplot(1, 3, 3)
    max_duration = np.percentile(notes['duration'], 100 - drop_percentile)
    sns.histplot(notes, x="duration", bins=np.linspace(0, max_duration, 21))

# %%
plot_distributions(raw_notes)

# %%
def notes_to_midi(
  notes: pd.DataFrame,
  out_file: str, 
  instrument_name: str,
  velocity: int = 100,  # note loudness
) -> pretty_midi.PrettyMIDI:

    pm = pretty_midi.PrettyMIDI()
    instrument = pretty_midi.Instrument(
      program=pretty_midi.instrument_name_to_program(
          instrument_name))

    prev_start = 0
    for i, note in notes.iterrows():
        start = float(prev_start + note['step'])
        end = float(start + note['duration'])
        note = pretty_midi.Note(
            velocity=velocity,
            pitch=int(note['pitch']),
            start=start,
            end=end,
        )
        instrument.notes.append(note)
        prev_start = start

    pm.instruments.append(instrument)
    pm.write(out_file)
    return pm

# %%
example_file = 'example.midi'
example_pm = notes_to_midi(
    raw_notes, out_file=example_file, instrument_name=instrument_name)

# %%
display_audio(example_pm)
# Out:
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
num_files = 5
all_notes = []
for f in midi_files:
    notes = midi_to_notes(f)
    all_notes.append(notes)

all_notes = pd.concat(all_notes)

# %%
n_notes = len(all_notes)
print('Number of notes parsed:', n_notes)
# Out:
# Number of notes parsed: 70288

# %%
key_order = ['pitch', 'step', 'duration']
train_notes = np.stack([all_notes[key] for key in key_order], axis=1)

# %%
notes_ds = tf.data.Dataset.from_tensor_slices(train_notes)
notes_ds.element_spec
# Out:
# 2022-12-05 16:08:50.365681: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-12-05 16:08:50.376018: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-05 16:08:50.380678: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-6D6L8D7): /proc/driver/nvidia/version does not exist
# 2022-12-05 16:08:50.481410: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorSpec(shape=(3,), dtype=tf.float64, name=None)

# %%
def create_sequences(
    dataset: tf.data.Dataset, 
    seq_length: int,
    vocab_size = 128,
) -> tf.data.Dataset:
    """Returns TF Dataset of sequence and label examples."""
    seq_length = seq_length+1

    # Take 1 extra for the labels
    windows = dataset.window(seq_length, shift=1, stride=1,
                              drop_remainder=True)

    # `flat_map` flattens the" dataset of datasets" into a dataset of tensors
    flatten = lambda x: x.batch(seq_length, drop_remainder=True)
    sequences = windows.flat_map(flatten)

    # Normalize note pitch
    def scale_pitch(x):
        x = x/[vocab_size,1.0,1.0]
        return x

    # Split the labels
    def split_labels(sequences):
        inputs = sequences[:-1]
        labels_dense = sequences[-1]
        labels = {key:labels_dense[i] for i,key in enumerate(key_order)}

        return scale_pitch(inputs), labels

    return sequences.map(split_labels, num_parallel_calls=tf.data.AUTOTUNE)

# %%
seq_length = 25
vocab_size = 128
seq_ds = create_sequences(notes_ds, seq_length, vocab_size)
seq_ds.element_spec
# Out:
# (TensorSpec(shape=(25, 3), dtype=tf.float64, name=None),
#  {'pitch': TensorSpec(shape=(), dtype=tf.float64, name=None),
#   'step': TensorSpec(shape=(), dtype=tf.float64, name=None),
#   'duration': TensorSpec(shape=(), dtype=tf.float64, name=None)})

# %%
for seq, target in seq_ds.take(1):
    print('sequence shape:', seq.shape)
    print('sequence elements (first 10):', seq[0: 10])
    print()
    print('target:', target)
# Out:
# sequence shape: (25, 3)
# sequence elements (first 10): tf.Tensor(
# [[0.265625   0.         0.3550295 ]
#  [0.6015625  0.         1.800532  ]
#  [0.4140625  0.3550295  0.29646617]
#  [0.4296875  0.29646617 0.28458125]
#  [0.40625    0.         0.28458125]
#  [0.4453125  0.28458125 0.27896408]
#  [0.3984375  0.         0.27896408]
#  [0.453125   0.27896408 0.2884615 ]
#  [0.390625   0.         0.2884615 ]
#  [0.46875    0.2884615  0.2970295 ]], shape=(10, 3), dtype=float64)
#
# target: {'pitch': <tf.Tensor: shape=(), dtype=float64, numpy=74.0>, 'step': <tf.Tensor: shape=(), dtype=float64, numpy=0.0>, 'duration': <tf.Tensor: shape=(), dtype=float64, numpy=1.7459862499999996>}

# %%
batch_size = 64
buffer_size = n_notes - seq_length  # the number of items in the dataset
train_ds = (seq_ds
            .shuffle(buffer_size)
            .batch(batch_size, drop_remainder=True)
            .cache()
            .prefetch(tf.data.experimental.AUTOTUNE))

# %%
train_ds.element_spec
# Out:
# (TensorSpec(shape=(64, 25, 3), dtype=tf.float64, name=None),
#  {'pitch': TensorSpec(shape=(64,), dtype=tf.float64, name=None),
#   'step': TensorSpec(shape=(64,), dtype=tf.float64, name=None),
#   'duration': TensorSpec(shape=(64,), dtype=tf.float64, name=None)})

# %%
def mse_with_positive_pressure(y_true: tf.Tensor, y_pred: tf.Tensor):
    mse = (y_true - y_pred) ** 2
    positive_pressure = 10 * tf.maximum(-y_pred, 0.0)
    return tf.reduce_mean(mse + positive_pressure)

# %%
input_shape = (seq_length, 3)
learning_rate = 0.005

inputs = tf.keras.Input(input_shape)
x = tf.keras.layers.LSTM(128)(inputs)

outputs = {
  'pitch': tf.keras.layers.Dense(128, name='pitch')(x),
  'step': tf.keras.layers.Dense(1, name='step')(x),
  'duration': tf.keras.layers.Dense(1, name='duration')(x),
}

model = tf.keras.Model(inputs, outputs)

loss = {
      'pitch': tf.keras.losses.SparseCategoricalCrossentropy(
          from_logits=True),
      'step': mse_with_positive_pressure,
      'duration': mse_with_positive_pressure,
}

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model.compile(
    loss=loss,
    loss_weights={
        'pitch': 0.05,
        'step': 1.0,
        'duration':1.0,
    },
    optimizer=optimizer,
)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 25, 3)]      0           []
#
#  lstm_1 (LSTM)                  (None, 128)          67584       ['input_2[0][0]']
#
#  duration (Dense)               (None, 1)            129         ['lstm_1[0][0]']
#
#  pitch (Dense)                  (None, 128)          16512       ['lstm_1[0][0]']
#
#  step (Dense)                   (None, 1)            129         ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 84,354
# Trainable params: 84,354
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
losses = model.evaluate(train_ds, return_dict=True)
losses
# Out:
# 2022-12-05 16:17:34.890305: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 13042 of 70263
# 2022-12-05 16:17:44.891124: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 27488 of 70263
# 2022-12-05 16:17:54.890579: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 42818 of 70263
# 2022-12-05 16:18:04.890299: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 51400 of 70263
# 2022-12-05 16:18:14.899411: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 56863 of 70263
# 2022-12-05 16:18:24.903746: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 61533 of 70263
# 2022-12-05 16:18:34.891069: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:390] Filling up shuffle buffer (this may take a while): 67891 of 70263
# 2022-12-05 16:18:38.218941: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:415] Shuffle buffer filled.
# 1097/1097 [==============================] - 185s 97ms/step - loss: 0.4769 - duration_loss: 0.2083 - pitch_loss: 4.8542 - step_loss: 0.0258
# {'loss': 0.4768699109554291,
#  'duration_loss': 0.20833168923854828,
#  'pitch_loss': 4.854243278503418,
#  'step_loss': 0.025826171040534973}

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='./training_checkpoints/ckpt_{epoch}',
        save_weights_only=True),
    tf.keras.callbacks.EarlyStopping(
        monitor='loss',
        patience=5,
        verbose=1,
        restore_best_weights=True),
]

# %%
# %%time
epochs = 5

history = model.fit(
    train_ds,
    epochs=epochs,
    callbacks=callbacks,
)
# Out:
# Epoch 1/5
# 1097/1097 [==============================] - 101s 92ms/step - loss: 0.2979 - duration_loss: 0.0861 - pitch_loss: 3.8811 - step_loss: 0.0177
# Epoch 2/5
# 1097/1097 [==============================] - 107s 97ms/step - loss: 0.2974 - duration_loss: 0.0868 - pitch_loss: 3.8658 - step_loss: 0.0173
# Epoch 3/5
# 1097/1097 [==============================] - 76s 69ms/step - loss: 0.2932 - duration_loss: 0.0836 - pitch_loss: 3.8485 - step_loss: 0.0172
# Epoch 4/5
# 1097/1097 [==============================] - 72s 65ms/step - loss: 0.2941 - duration_loss: 0.0836 - pitch_loss: 3.8553 - step_loss: 0.0177
# Epoch 5/5
# 1097/1097 [==============================] - 72s 65ms/step - loss: 0.2899 - duration_loss: 0.0814 - pitch_loss: 3.8328 - step_loss: 0.0169
# CPU times: user 13min 37s, sys: 4min 47s, total: 18min 25s
# Wall time: 7min 6s

# %%
plt.plot(history.epoch, history.history['loss'], label='total loss')
plt.show()

# %%
def predict_next_note(
    notes: np.ndarray, 
    keras_model: tf.keras.Model, 
    temperature: float = 1.0) -> int:
    """Generates a note IDs using a trained sequence model."""

    assert temperature > 0

    # Add batch dimension
    inputs = tf.expand_dims(notes, 0)

    predictions = model.predict(inputs)
    pitch_logits = predictions['pitch']
    step = predictions['step']
    duration = predictions['duration']

    pitch_logits /= temperature
    pitch = tf.random.categorical(pitch_logits, num_samples=1)
    pitch = tf.squeeze(pitch, axis=-1)
    duration = tf.squeeze(duration, axis=-1)
    step = tf.squeeze(step, axis=-1)

    # `step` and `duration` values should be non-negative
    step = tf.maximum(0, step)
    duration = tf.maximum(0, duration)

    return int(pitch), float(step), float(duration)

# %%
temperature = 2.0
num_predictions = 120

sample_notes = np.stack([raw_notes[key] for key in key_order], axis=1)

# The initial sequence of notes; pitch is normalized similar to training
# sequences
input_notes = (
    sample_notes[:seq_length] / np.array([vocab_size, 1, 1]))

generated_notes = []
prev_start = 0
for _ in range(num_predictions):
    pitch, step, duration = predict_next_note(input_notes, model, temperature)
    start = prev_start + step
    end = start + duration
    input_note = (pitch, step, duration)
    generated_notes.append((*input_note, start, end))
    input_notes = np.delete(input_notes, 0, axis=0)
    input_notes = np.append(input_notes, np.expand_dims(input_note, 0), axis=0)
    prev_start = start

generated_notes = pd.DataFrame(
    generated_notes, columns=(*key_order, 'start', 'end'))
# Out:
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step

# %%
generated_notes.head(10)
# Out:
#    pitch      step  duration     start       end
# 0     67  0.105252  0.486145  0.105252  0.591397
# 1     97  0.198069  1.428377  0.303321  1.731698
# 2     97  0.217025  1.547900  0.520346  2.068246
# 3     61  0.219823  1.565383  0.740169  2.305552
# 4     88  0.220203  1.567708  0.960372  2.528080
# 5     65  0.220265  1.568035  1.180637  2.748672
# 6     42  0.220267  1.568076  1.400904  2.968979
# 7     86  0.220021  1.567999  1.620925  3.188924
# 8     28  0.220273  1.568084  1.841198  3.409282
# 9     82  0.217550  1.567016  2.058748  3.625764

# %%
out_file = 'output.mid'
out_pm = notes_to_midi(
    generated_notes, out_file=out_file, instrument_name=instrument_name)
display_audio(out_pm)
# Out:
# fluidsynth: error: Unknown integer parameter 'synth.sample-rate'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot_piano_roll(generated_notes)

# %%
plot_distributions(generated_notes)
